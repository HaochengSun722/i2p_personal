# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp

import scipy.stats as sps

# %%
d2 = pd.read_csv('coursework_1_data_2019_add.csv')

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   local_authority_area   152 non-null    object
#  1   2008_cases_total       152 non-null    int64
#  2   2013_cases_total       152 non-null    int64
#  3   2018_cases_total       152 non-null    int64
#  4   2008_pop_total         152 non-null    int64
#  5   2013_pop_total         152 non-null    int64
#  6   2018_pop_total         152 non-null    int64
#  7   2008_cases_male        152 non-null    int64
#  8   2013_cases_male        152 non-null    int64
#  9   2018_cases_male        152 non-null    int64
#  10  2008_pop_male          152 non-null    int64
#  11  2013_pop_male          152 non-null    int64
#  12  2018_pop_male          152 non-null    int64
#  13  2008_cases_female      152 non-null    int64
#  14  2013_cases_female      152 non-null    int64
#  15  2018_cases_female      152 non-null    int64
#  16  2008_pop_female        152 non-null    int64
#  17  2013_pop_female        152 non-null    int64
#  18  2018_pop_female        152 non-null    int64
#  19  total_budget           152 non-null    int64
#  20  clean_air              152 non-null    int64
#  21  clean_environ          152 non-null    int64
#  22  health_training        152 non-null    int64
#  23  school_awareness       152 non-null    int64
#  24  media_awareness        152 non-null    int64
#  25  sub_counselling        152 non-null    int64
#  26  region                 152 non-null    object
#  27  local_authority_type   152 non-null    object
#  28  Unnamed: 28            0 non-null      float64
#  29  2008_proportion        152 non-null    float64
#  30  2013_proportion        152 non-null    float64
#  31  2018_proportion        152 non-null    float64
#  32  if_increase            152 non-null    int64
#  33  clean_air_proportion   152 non-null    float64
#  34  clean_env_proportion   152 non-null    float64
#  35  health_proportion      152 non-null    float64
#  36  school_proportion      152 non-null    float64
#  37  media_proportion       152 non-null    float64
#  38  sub_proportion         152 non-null    float64
#  39  GAP_08_18              152 non-null    float64
#  40  mean_cases_proportion  152 non-null    float64
#  41  Unnamed: 41            0 non-null      float64
#  42  Unnamed: 42            1 non-null      object
# dtypes: float64(13), int64(26), object(4)
# memory usage: 51.2+ KB

# %%
d2=d2.drop(['Unnamed: 28','Unnamed: 41','Unnamed: 42'],axis=1)
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   local_authority_area   152 non-null    object
#  1   2008_cases_total       152 non-null    int64
#  2   2013_cases_total       152 non-null    int64
#  3   2018_cases_total       152 non-null    int64
#  4   2008_pop_total         152 non-null    int64
#  5   2013_pop_total         152 non-null    int64
#  6   2018_pop_total         152 non-null    int64
#  7   2008_cases_male        152 non-null    int64
#  8   2013_cases_male        152 non-null    int64
#  9   2018_cases_male        152 non-null    int64
#  10  2008_pop_male          152 non-null    int64
#  11  2013_pop_male          152 non-null    int64
#  12  2018_pop_male          152 non-null    int64
#  13  2008_cases_female      152 non-null    int64
#  14  2013_cases_female      152 non-null    int64
#  15  2018_cases_female      152 non-null    int64
#  16  2008_pop_female        152 non-null    int64
#  17  2013_pop_female        152 non-null    int64
#  18  2018_pop_female        152 non-null    int64
#  19  total_budget           152 non-null    int64
#  20  clean_air              152 non-null    int64
#  21  clean_environ          152 non-null    int64
#  22  health_training        152 non-null    int64
#  23  school_awareness       152 non-null    int64
#  24  media_awareness        152 non-null    int64
#  25  sub_counselling        152 non-null    int64
#  26  region                 152 non-null    object
#  27  local_authority_type   152 non-null    object
#  28  2008_proportion        152 non-null    float64
#  29  2013_proportion        152 non-null    float64
#  30  2018_proportion        152 non-null    float64
#  31  if_increase            152 non-null    int64
#  32  clean_air_proportion   152 non-null    float64
#  33  clean_env_proportion   152 non-null    float64
#  34  health_proportion      152 non-null    float64
#  35  school_proportion      152 non-null    float64
#  36  media_proportion       152 non-null    float64
#  37  sub_proportion         152 non-null    float64
#  38  GAP_08_18              152 non-null    float64
#  39  mean_cases_proportion  152 non-null    float64
# dtypes: float64(11), int64(26), object(3)
# memory usage: 47.6+ KB

# %%
X = d2['mean_cases_proportion']
Y = d2['total_budget']

plt.xlabel('mean_incidence')
plt.ylabel('total_budget')

a = plt.plot(X,Y,'.', label='original data')
plt.xlim(0.0009,0.0085)
plt.ylim(1500,1200000)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = 3901752.33 x + 257623.625
# Rsq =  0.0006514543178242983
# p-value =  0.7549422352214554

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

simple_regression_model_2 = smf.ols(formula='mean_cases_proportion ~ total_budget',data=d2).fit()
print(simple_regression_model_2.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     mean_cases_proportion   R-squared:                       0.001
# Model:                               OLS   Adj. R-squared:                 -0.006
# Method:                    Least Squares   F-statistic:                   0.09778
# Date:                   Sat, 14 Nov 2020   Prob (F-statistic):              0.755
# Time:                           17:36:54   Log-Likelihood:                 786.25
# No. Observations:                    152   AIC:                            -1569.
# Df Residuals:                        150   BIC:                            -1562.
# Df Model:                              1
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0032      0.000     17.549      0.000       0.003       0.004
# total_budget   1.67e-10   5.34e-10      0.313      0.755   -8.88e-10    1.22e-09
# ==============================================================================
# Omnibus:                       27.345   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.034
# Skew:                           1.059   Prob(JB):                     1.50e-08
# Kurtosis:                       4.099   Cond. No.                     5.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# produce regression plots
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(simple_regression_model_2, 'total_budget', fig=fig)

# %%
plt.figure()
#ols.fit().model is a method to access to the residual.
simple_regression_model_2.resid.plot.density()
plt.show()

# %%
# plot 
plt.scatter(simple_regression_model_2.fittedvalues, simple_regression_model_2.resid)
# adding title and labels
plt.xlabel('Fitted total_budget')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of total_budget')
plt.show()

# %%
#######

# %%
# Load the data into data frames

d1 = pd.read_csv('coursework_1_data_2019_add.csv')

# %%
d1.info()

# %%
d1=d1.drop(['Unnamed: 28','Unnamed: 40','Unnamed: 41','Unnamed: 42'],axis=1)
d1.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-043ea8e86440> in <module>
# ----> 1 d1=d1.drop(['Unnamed: 28','Unnamed: 40','Unnamed: 41','Unnamed: 42'],axis=1)
#       2 d1.head()
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3916                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3917             else:
# -> 3918                 new_axis = axis.drop(labels, errors=errors)
#    3919             result = self.reindex(**{axis_name: new_axis})
#    3920
#
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5276         if mask.any():
#    5277             if errors != "ignore":
# -> 5278                 raise KeyError(f"{labels[mask]} not found in axis")
#    5279             indexer = indexer[~mask]
#    5280         return self.delete(indexer)
#
# KeyError: "['Unnamed: 28' 'Unnamed: 40' 'Unnamed: 41' 'Unnamed: 42'] not found in axis"

# %%
d1.head()
# Out:
#            local_authority_area  2008_cases_total  2013_cases_total  \
# 0          Barking and Dagenham               593               619
# 1                        Barnet               539               594
# 2                      Barnsley               360               451
# 3  Bath and North East Somerset               456               421
# 4                       Bedford               311               327
#
#    2018_cases_total  2008_pop_total  2013_pop_total  2018_pop_total  \
# 0               763          172684          179030          181779
# 1               773          340435          344062          355955
# 2               527          226755          244010          257883
# 3               494          178625          172975          189334
# 4               367          158185          164807          170463
#
#    2008_cases_male  2013_cases_male  2018_cases_male  ...  \
# 0              187              190              230  ...
# 1              212              204              292  ...
# 2              148              186              212  ...
# 3              157              129              156  ...
# 4              138              145              156  ...
#
#                            2013_proportion  \
# 0                                   0.0035
# 1                                   0.0017
# 2                                   0.0018
# 3                                   0.0024
# 4                                   0.0020
#
#                            2018_proportion  if_increase  \
# 0                                   0.0042            1
# 1                                   0.0022            1
# 2                                   0.0020            1
# 3                                   0.0026            1
# 4                                   0.0022            1
#
#                       clean_air_proportion  \
# 0                                   0.1511
# 1                                   0.2273
# 2                                   0.2562
# 3                                   0.2050
# 4                                   0.2846
#
#                       clean_env_proportion  \
# 0                                   0.1583
# 1                                   0.0773
# 2                                   0.2812
# 3                                   0.2609
# 4                                   0.4000
#
#                          health_proportion  \
# 0                                   0.1295
# 1                                   0.1045
# 2                                   0.0312
# 3                                   0.1180
# 4                                   0.1308
#
#                          school_proportion  \
# 0                                   0.2950
# 1                                   0.3364
# 2                                   0.1625
# 3                                   0.3106
# 4                                   0.0615
#
#                           media_proportion  \
# 0                                   0.1295
# 1                                   0.1364
# 2                                   0.1812
# 3                                   0.0621
# 4                                   0.0231
#
#                             sub_proportion  \
# 0                                   0.1367
# 1                                   0.1182
# 2                                   0.0875
# 3                                   0.0435
# 4                                   0.1000
#
#                                  GAP_08_18
# 0                                   0.0008
# 1                                   0.0006
# 2                                   0.0005
# 3                                   0.0001
# 4                                   0.0002
#
# [5 rows x 39 columns]

# %%
X = d1['total_budget']
Y = d1['GAP_08_18']

plt.xlabel('total_budget')
plt.ylabel('cases_gap_08_18')

a = plt.plot(X,Y,'.', label='original data')
plt.xlim(2000,1170000)
plt.ylim(-0.0007,0.0011)

slope, intercept, r_value, p_value, std_err = sps.linregress(X, Y) 

b = plt.plot(X, X*slope + intercept, 'r', label = 'fitted line') # Plot the regression line.

plt.legend()
plt.show()

print("y =", round(slope,3), "x +", round(intercept,3))
print("Rsq = ", r_value**2)
print("p-value = ", p_value)
# Out:
# y = -0.0 x + 0.0
# Rsq =  0.03097164257208089
# p-value =  0.030100430731130747

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

simple_regression_model_1 = smf.ols(formula='GAP_08_18 ~ total_budget',data=d1).fit()
print(simple_regression_model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              GAP_08_18   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     4.794
# Date:                Sat, 14 Nov 2020   Prob (F-statistic):             0.0301
# Time:                        17:07:13   Log-Likelihood:                 1046.7
# No. Observations:                 152   AIC:                            -2089.
# Df Residuals:                     150   BIC:                            -2083.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0004   3.29e-05     12.344      0.000       0.000       0.000
# total_budget -2.107e-10   9.62e-11     -2.190      0.030   -4.01e-10   -2.06e-11
# ==============================================================================
# Omnibus:                        8.438   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):               11.652
# Skew:                          -0.313   Prob(JB):                      0.00295
# Kurtosis:                       4.204   Cond. No.                     5.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# produce regression plots
fig = plt.figure(figsize=(10,8))
fig = sm.graphics.plot_regress_exog(simple_regression_model_1, 'total_budget', fig=fig)

# %%
plt.figure()
#ols.fit().model is a method to access to the residual.
simple_regression_model_1.resid.plot.density()
plt.show()

# %%
# plot 
plt.scatter(simple_regression_model_1.fittedvalues, simple_regression_model_1.resid)
# adding title and labels
plt.xlabel('Fitted total_budget')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of total_budget')
plt.show()

# %%
#######

# %%
condition_x= pd.read_csv('coursework_1_data_2019_withoutgender.csv')

# %%
condition_x_drop=condition_x.drop(['local_authority_area','2008_cases_total','2013_cases_total','2018_cases_total','2008_pop_total',
                                  '2013_pop_total','2018_pop_total','total_budget','clean_air','clean_environ','health_training','school_awareness',
                                  'media_awareness','sub_counselling','2008_proportion','2013_proportion','2018_proportion'], axis=1)
condition_x_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   region                152 non-null    object
#  1   local_authority_type  152 non-null    object
#  2   Unnamed: 16           0 non-null      float64
#  3   case_gap              152 non-null    float64
#  4   clean_air_proportion  152 non-null    float64
#  5   clean_env_proportion  152 non-null    float64
#  6   health_proportion     152 non-null    float64
#  7   school_proportion     152 non-null    float64
#  8   media_proportion      152 non-null    float64
#  9   sub_proportion        152 non-null    float64
#  10  Unnamed: 27           0 non-null      float64
#  11  Unnamed: 28           0 non-null      float64
#  12  Unnamed: 29           0 non-null      float64
#  13  Unnamed: 30           0 non-null      float64
#  14  Unnamed: 31           0 non-null      float64
#  15  Unnamed: 32           0 non-null      float64
#  16  Unnamed: 33           0 non-null      float64
#  17  Unnamed: 34           0 non-null      float64
#  18  Unnamed: 35           0 non-null      float64
#  19  Unnamed: 36           0 non-null      float64
#  20  Unnamed: 37           0 non-null      float64
#  21  Unnamed: 38           0 non-null      float64
#  22  Unnamed: 39           0 non-null      float64
#  23  Unnamed: 40           0 non-null      float64
#  24  Unnamed: 41           0 non-null      float64
#  25  Unnamed: 42           1 non-null      object
# dtypes: float64(23), object(3)
# memory usage: 31.0+ KB

# %%
condition_x=condition_x_drop.drop(['Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41','Unnamed: 42'],axis =1)

# %%
condition_x=condition_x.drop(['Unnamed: 16'],axis=1)

# %%
condition_x.head()
# Out:
#                      region  local_authority_type  \
# 0                    London        london_borough
# 1                    London        london_borough
# 2  Yorkshire and the Humber  metropolitan_borough
# 3                South West     unitary_authority
# 4           East of England     unitary_authority
#
#                                   case_gap  \
# 0                                   0.0008
# 1                                   0.0006
# 2                                   0.0005
# 3                                   0.0001
# 4                                   0.0002
#
#                       clean_air_proportion  \
# 0                                   0.1511
# 1                                   0.2273
# 2                                   0.2562
# 3                                   0.2050
# 4                                   0.2846
#
#                       clean_env_proportion  \
# 0                                   0.1583
# 1                                   0.0773
# 2                                   0.2812
# 3                                   0.2609
# 4                                   0.4000
#
#                          health_proportion  \
# 0                                   0.1295
# 1                                   0.1045
# 2                                   0.0312
# 3                                   0.1180
# 4                                   0.1308
#
#                          school_proportion  \
# 0                                   0.2950
# 1                                   0.3364
# 2                                   0.1625
# 3                                   0.3106
# 4                                   0.0615
#
#                           media_proportion  \
# 0                                   0.1295
# 1                                   0.1364
# 2                                   0.1812
# 3                                   0.0621
# 4                                   0.0231
#
#                             sub_proportion
# 0                                   0.1367
# 1                                   0.1182
# 2                                   0.0875
# 3                                   0.0435
# 4                                   0.1000

# %%
condition_x_numeric = pd.get_dummies(condition_x)

# %%
condition_x_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   case_gap                                      152 non-null    float64
#  1   clean_air_proportion                          152 non-null    float64
#  2   clean_env_proportion                          152 non-null    float64
#  3   health_proportion                             152 non-null    float64
#  4   school_proportion                             152 non-null    float64
#  5   media_proportion                              152 non-null    float64
#  6   sub_proportion                                152 non-null    float64
#  7   region_East Midlands                          152 non-null    uint8
#  8   region_East of England                        152 non-null    uint8
#  9   region_London                                 152 non-null    uint8
#  10  region_North East                             152 non-null    uint8
#  11  region_North West                             152 non-null    uint8
#  12  region_South East                             152 non-null    uint8
#  13  region_South West                             152 non-null    uint8
#  14  region_West Midlands                          152 non-null    uint8
#  15  region_Yorkshire and the Humber               152 non-null    uint8
#  16  local_authority_type_london_borough           152 non-null    uint8
#  17  local_authority_type_metropolitan_borough     152 non-null    uint8
#  18  local_authority_type_non_metropolitan_county  152 non-null    uint8
#  19  local_authority_type_other_london             152 non-null    uint8
#  20  local_authority_type_unitary_authority        152 non-null    uint8
# dtypes: float64(7), uint8(14)
# memory usage: 10.5 KB

# %%
####select reference level--'region_London','local_authority_type_london_borough'
condition_x_final=condition_x_numeric.drop(['region_London','local_authority_type_london_borough'],axis=1)
condition_x_final
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   case_gap                                      152 non-null    float64
#  1   clean_air_proportion                          152 non-null    float64
#  2   clean_env_proportion                          152 non-null    float64
#  3   health_proportion                             152 non-null    float64
#  4   school_proportion                             152 non-null    float64
#  5   media_proportion                              152 non-null    float64
#  6   sub_proportion                                152 non-null    float64
#  7   region_East Midlands                          152 non-null    uint8
#  8   region_East of England                        152 non-null    uint8
#  9   region_North East                             152 non-null    uint8
#  10  region_North West                             152 non-null    uint8
#  11  region_South East                             152 non-null    uint8
#  12  region_South West                             152 non-null    uint8
#  13  region_West Midlands                          152 non-null    uint8
#  14  region_Yorkshire and the Humber               152 non-null    uint8
#  15  local_authority_type_metropolitan_borough     152 non-null    uint8
#  16  local_authority_type_non_metropolitan_county  152 non-null    uint8
#  17  local_authority_type_other_london             152 non-null    uint8
#  18  local_authority_type_unitary_authority        152 non-null    uint8
# dtypes: float64(7), uint8(12)
# memory usage: 10.2 KB

# %%
# calculating VIF
# This function is partially from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: the max VIF value before the feature is removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
condition_x_final.columns
# Out:
# Index(['case_gap', 'clean_air_proportion', 'clean_env_proportion',
#        'health_proportion', 'school_proportion', 'media_proportion',
#        'sub_proportion', 'region_East Midlands', 'region_East of England',
#        'region_North East', 'region_North West', 'region_South East',
#        'region_South West', 'region_West Midlands',
#        'region_Yorkshire and the Humber',
#        'local_authority_type_metropolitan_borough',
#        'local_authority_type_non_metropolitan_county',
#        'local_authority_type_other_london',
#        'local_authority_type_unitary_authority'],
#       dtype='object')

# %%
# using VIF on the bike_rental dataset

df_predictors_selected_VIF = drop_column_using_vif_(condition_x_final.drop('case_gap', axis=1))
print("The columns remaining after VIF selection are:")
print(df_predictors_selected_VIF.columns)
# Out:
# Dropping: clean_env_proportion
# Dropping: region_East Midlands
# Dropping: local_authority_type_metropolitan_borough
# The columns remaining after VIF selection are:
# Index(['clean_air_proportion', 'health_proportion', 'school_proportion',
#        'media_proportion', 'sub_proportion', 'region_East of England',
#        'region_North East', 'region_North West', 'region_South East',
#        'region_South West', 'region_West Midlands',
#        'region_Yorkshire and the Humber',
#        'local_authority_type_non_metropolitan_county',
#        'local_authority_type_other_london',
#        'local_authority_type_unitary_authority'],
#       dtype='object')
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
model_condition_x = sm.OLS(endog=condition_x_final[['case_gap']], exog=sm.add_constant(df_predictors_selected_VIF)).fit()
model_condition_x.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               case_gap   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     24.05
# Date:                Sun, 15 Nov 2020   Prob (F-statistic):           4.46e-31
# Time:                        10:34:38   Log-Likelihood:                 1142.8
# No. Observations:                 152   AIC:                            -2254.
# Df Residuals:                     136   BIC:                            -2205.
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                            0.0006      0.000      6.367      0.000       0.000       0.001
# clean_air_proportion                            -0.0003      0.000     -1.941      0.054      -0.001    6.48e-06
# health_proportion                                0.0002      0.000      0.538      0.591      -0.000       0.001
# school_proportion                               -0.0007      0.000     -5.464      0.000      -0.001      -0.000
# media_proportion                                 0.0011      0.000      4.778      0.000       0.001       0.002
# sub_proportion                                   0.0009      0.000      2.509      0.013       0.000       0.002
# region_East of England                          -0.0002   5.35e-05     -3.777      0.000      -0.000   -9.62e-05
# region_North East                               -0.0001   4.79e-05     -2.531      0.012      -0.000   -2.65e-05
# region_North West                            -6.729e-05   3.69e-05     -1.825      0.070      -0.000    5.62e-06
# region_South East                               -0.0002   4.66e-05     -4.491      0.000      -0.000      -0.000
# region_South West                               -0.0002   4.87e-05     -4.882      0.000      -0.000      -0.000
# region_West Midlands                            -0.0002   4.62e-05     -5.376      0.000      -0.000      -0.000
# region_Yorkshire and the Humber                 -0.0001   4.37e-05     -3.374      0.001      -0.000    -6.1e-05
# local_authority_type_non_metropolitan_county    -0.0003   3.85e-05     -7.339      0.000      -0.000      -0.000
# local_authority_type_other_london               -0.0003      0.000     -1.865      0.064      -0.001    1.61e-05
# local_authority_type_unitary_authority          -0.0002   3.23e-05     -6.972      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                       12.556   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               26.804
# Skew:                          -0.287   Prob(JB):                     1.51e-06
# Kurtosis:                       4.975   Cond. No.                         39.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(model_condition_x.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               case_gap   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     24.05
# Date:                Sun, 15 Nov 2020   Prob (F-statistic):           4.46e-31
# Time:                        09:28:37   Log-Likelihood:                 1142.8
# No. Observations:                 152   AIC:                            -2254.
# Df Residuals:                     136   BIC:                            -2205.
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# const                                            0.0006      0.000      6.367      0.000       0.000       0.001
# clean_air_proportion                            -0.0003      0.000     -1.941      0.054      -0.001    6.48e-06
# health_proportion                                0.0002      0.000      0.538      0.591      -0.000       0.001
# school_proportion                               -0.0007      0.000     -5.464      0.000      -0.001      -0.000
# media_proportion                                 0.0011      0.000      4.778      0.000       0.001       0.002
# sub_proportion                                   0.0009      0.000      2.509      0.013       0.000       0.002
# region_East of England                          -0.0002   5.35e-05     -3.777      0.000      -0.000   -9.62e-05
# region_North East                               -0.0001   4.79e-05     -2.531      0.012      -0.000   -2.65e-05
# region_North West                            -6.729e-05   3.69e-05     -1.825      0.070      -0.000    5.62e-06
# region_South East                               -0.0002   4.66e-05     -4.491      0.000      -0.000      -0.000
# region_South West                               -0.0002   4.87e-05     -4.882      0.000      -0.000      -0.000
# region_West Midlands                            -0.0002   4.62e-05     -5.376      0.000      -0.000      -0.000
# region_Yorkshire and the Humber                 -0.0001   4.37e-05     -3.374      0.001      -0.000    -6.1e-05
# local_authority_type_non_metropolitan_county    -0.0003   3.85e-05     -7.339      0.000      -0.000      -0.000
# local_authority_type_other_london               -0.0003      0.000     -1.865      0.064      -0.001    1.61e-05
# local_authority_type_unitary_authority          -0.0002   3.23e-05     -6.972      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                       12.556   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               26.804
# Skew:                          -0.287   Prob(JB):                     1.51e-06
# Kurtosis:                       4.975   Cond. No.                         39.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# plot 
plt.scatter(model_condition_x.fittedvalues, model_condition_x.resid)
# adding title and labels
plt.xlabel('Fitted case_gap')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of case_gap between 2008 and 2018')
plt.show()

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model_condition_x, 'clean_air_proportion', fig=fig)
